# %% [markdown]
# # Combined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np

# Function to create a subplot for each CSV file
def create_subplot(ax, dist_file, title):
    # Read the CSV file
    df_w_r = pd.read_csv(dist_file)
    # Extract unique lambda values
    lambda_values = df_w_r['Lambda State'].unique()
    # Generate a colormap to differentiate between lambda values
    colors = plt.cm.viridis(np.linspace(0, 1, len(lambda_values)))
    
    # Loop over each lambda value and plot
    for i, lambda_val in enumerate(lambda_values):
        df_subset = df_w_r[(df_w_r['Distance (nm)'] >= 0.60) & (df_w_r['Distance (nm)'] <= 0.95) & (df_w_r['Lambda State'] == lambda_val)]
        ax.plot(df_subset['Distance (nm)'], df_subset['Total Energy (kJ/mol)'], marker='|', linestyle='-', color=colors[i], label=f'Lambda State = {lambda_val}')

    # Set plot title and limits
    ax.set_title(title)
    ax.set_xlim(0.6, 0.95)
    # ax.set_ylim(-0.06, 0)
    # ax.axvline(x=1.75, color='black', linestyle='--')
    # ax.axvline(x=2.0, color='black', linestyle='--')
    ax.grid(True)

# Specify the directory to save the figures
save_dir = '/home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs'  # Replace with your desired directory path
os.makedirs(save_dir, exist_ok=True)

# Create a new figure with 3 subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Define file paths and titles
files_and_titles = [
    ('/home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/PME_no_mod_2024.3.csv', 'PME_no_mod'),
    ('/home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/PME_potential-shift.csv', 'PME_potential-shift'),
    ('/home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/PME_potential-switch.csv', 'PME_potential-switch')
]

# Loop through files and create subplots
for i, (ax, (dist_file, title)) in enumerate(zip(axs, files_and_titles)):
    create_subplot(ax, dist_file, title)
    ax.set_xlabel('Distance (nm)')
    ax.set_ylabel('U($\lambda$) (kJ/mol)')
    # if i == 0:  # Only the first subplot gets labeled axes
        # ax.set_xlabel('Distance (nm)')
        # ax.set_ylabel('U($\lambda$) (kJ/mol)')

# Adjust layout
plt.tight_layout()

# Create a single legend outside the plots
handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='center right', fontsize='medium', title='Lambda States')

# Save the combined plot
save_path = os.path.join(save_dir, 'combined_lambda_plots.png')
plt.savefig(save_path)
print(f'Combined plot saved to {save_path}')

# Show the combined plot
plt.show()

# Close the figure
plt.close()
# Out:
# <>:46: SyntaxWarning: invalid escape sequence '\l'
# <>:46: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_31182/1231806833.py:46: SyntaxWarning: invalid escape sequence '\l'
#   ax.set_ylabel('U($\lambda$) (kJ/mol)')
# Combined plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/combined_lambda_plots.png

# %% [markdown]
# # For potential-shift

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Path to the CSV file
DistFile = "/home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/PME_potential-shift.csv"  # Update with your actual CSV file path
# DistFile = "/Users/lwhitm1/Downloads/no_mods_75_9_w_FE.csv"

# Extract the base name of the CSV file without the extension
base_filename = os.path.splitext(os.path.basename(DistFile))[0]

# Read the CSV file
df_w_r = pd.read_csv(DistFile)

# Specify the directory to save the figures
save_dir = '/home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-shift'  # Replace with your desired directory path

# Create the output directory if it doesn't exist
os.makedirs(save_dir, exist_ok=True)

# Extract unique lambda values
lambda_values = df_w_r['Lambda State'].unique()

# Loop over each lambda value and plot
for lambda_val in lambda_values:
    # Create a new figure
    plt.figure(figsize=(12, 8))
    
    # Filter the DataFrame for the current lambda value and distance range
    df_subset = df_w_r[(df_w_r['Distance (nm)'] >= 0.6) & (df_w_r['Distance (nm)'] <= 0.95) & (df_w_r['Lambda State'] == lambda_val)]
    
    # Plot the data
    plt.plot(df_subset['Distance (nm)'], df_subset['Total Energy (kJ/mol)'], marker='|', linestyle='-')
    
    # Set plot labels and title
    plt.xlabel('Distance (nm)')
    plt.ylabel('Total Energy (kJ/mol)')
    plt.title(f'Total Energy (kJ/mol) vs. Distance for Lambda State = {lambda_val:.3f}')
    
    # Set x and y limits
    plt.xlim(0.6, 0.95)
    plt.ylim(min(df_subset['Total Energy (kJ/mol)']), max(df_subset['Total Energy (kJ/mol)']))
    
    # Enable grid
    plt.grid(True)
    
    # Save the figure
    save_path = os.path.join(save_dir, f'{base_filename}_lambda_{lambda_val:.3f}.png')
    plt.savefig(save_path)
    
    print(f'Plot saved to {save_path}')

    # Show the plot
    plt.show()
    
    plt.close()
# Out:
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-shift/PME_potential-shift_lambda_0.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-shift/PME_potential-shift_lambda_1.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-shift/PME_potential-shift_lambda_2.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-shift/PME_potential-shift_lambda_3.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-shift/PME_potential-shift_lambda_4.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-shift/PME_potential-shift_lambda_5.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-shift/PME_potential-shift_lambda_6.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-shift/PME_potential-shift_lambda_7.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-shift/PME_potential-shift_lambda_8.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-shift/PME_potential-shift_lambda_9.000.png
# /tmp/ipykernel_30820/221711150.py:42: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   plt.ylim(min(df_subset['Total Energy (kJ/mol)']), max(df_subset['Total Energy (kJ/mol)']))
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-shift/PME_potential-shift_lambda_10.000.png

# %% [markdown]
# # For potential-switch

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Path to the CSV file
DistFile = "/home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/PME_potential-switch.csv"  # Update with your actual CSV file path
# DistFile = "/Users/lwhitm1/Downloads/no_mods_75_9_w_FE.csv"

# Extract the base name of the CSV file without the extension
base_filename = os.path.splitext(os.path.basename(DistFile))[0]

# Read the CSV file
df_w_r = pd.read_csv(DistFile)

# Specify the directory to save the figures
save_dir = '/home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-switch'  # Replace with your desired directory path

# Create the output directory if it doesn't exist
os.makedirs(save_dir, exist_ok=True)

# Extract unique lambda values
lambda_values = df_w_r['Lambda State'].unique()

# Loop over each lambda value and plot
for lambda_val in lambda_values:
    # Create a new figure
    plt.figure(figsize=(12, 8))
    
    # Filter the DataFrame for the current lambda value and distance range
    df_subset = df_w_r[(df_w_r['Distance (nm)'] >= 0.6) & (df_w_r['Distance (nm)'] <= 0.95) & (df_w_r['Lambda State'] == lambda_val)]
    
    # Plot the data
    plt.plot(df_subset['Distance (nm)'], df_subset['Total Energy (kJ/mol)'], marker='|', linestyle='-')
    
    # Set plot labels and title
    plt.xlabel('Distance (nm)')
    plt.ylabel('Total Energy (kJ/mol)')
    plt.title(f'Total Energy (kJ/mol) vs. Distance for Lambda State = {lambda_val:.3f}')
    
    # Set x and y limits
    plt.xlim(0.6, 0.95)
    plt.ylim(min(df_subset['Total Energy (kJ/mol)']), max(df_subset['Total Energy (kJ/mol)']))
    
    # Enable grid
    plt.grid(True)
    
    # Save the figure
    save_path = os.path.join(save_dir, f'{base_filename}_lambda_{lambda_val:.3f}.png')
    plt.savefig(save_path)
    
    print(f'Plot saved to {save_path}')

    # Show the plot
    plt.show()
    
    plt.close()
# Out:
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-switch/PME_potential-switch_lambda_0.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-switch/PME_potential-switch_lambda_1.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-switch/PME_potential-switch_lambda_2.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-switch/PME_potential-switch_lambda_3.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-switch/PME_potential-switch_lambda_4.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-switch/PME_potential-switch_lambda_5.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-switch/PME_potential-switch_lambda_6.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-switch/PME_potential-switch_lambda_7.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-switch/PME_potential-switch_lambda_8.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-switch/PME_potential-switch_lambda_9.000.png
# /tmp/ipykernel_30820/2421631179.py:42: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   plt.ylim(min(df_subset['Total Energy (kJ/mol)']), max(df_subset['Total Energy (kJ/mol)']))
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/potential-switch/PME_potential-switch_lambda_10.000.png

# %% [markdown]
# # PME with no vdw-modifier

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Path to the CSV file
DistFile = "/home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/PME_no_mod_2024.3.csv"  # Update with your actual CSV file path
# DistFile = "/Users/lwhitm1/Downloads/no_mods_75_9_w_FE.csv"

# Extract the base name of the CSV file without the extension
base_filename = os.path.splitext(os.path.basename(DistFile))[0]

# Read the CSV file
df_w_r = pd.read_csv(DistFile)

# Specify the directory to save the figures
save_dir = '/home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/no_mods'  # Replace with your desired directory path

# Create the output directory if it doesn't exist
os.makedirs(save_dir, exist_ok=True)

# Extract unique lambda values
lambda_values = df_w_r['Lambda State'].unique()

# Loop over each lambda value and plot
for lambda_val in lambda_values:
    # Create a new figure
    plt.figure(figsize=(12, 8))
    
    # Filter the DataFrame for the current lambda value and distance range
    df_subset = df_w_r[(df_w_r['Distance (nm)'] >= 0.6) & (df_w_r['Distance (nm)'] <= 0.95) & (df_w_r['Lambda State'] == lambda_val)]
    
    # Plot the data
    plt.plot(df_subset['Distance (nm)'], df_subset['Total Energy (kJ/mol)'], marker='|', linestyle='-')
    
    # Set plot labels and title
    plt.xlabel('Distance (nm)')
    plt.ylabel('Total Energy (kJ/mol)')
    plt.title(f'Total Energy (kJ/mol) vs. Distance for Lambda State = {lambda_val:.3f}')
    
    # Set x and y limits
    plt.xlim(0.6, 0.95)
    plt.ylim(min(df_subset['Total Energy (kJ/mol)']), max(df_subset['Total Energy (kJ/mol)']))
    
    # Enable grid
    plt.grid(True)
    
    # Save the figure
    save_path = os.path.join(save_dir, f'{base_filename}_lambda_{lambda_val:.3f}.png')
    plt.savefig(save_path)
    
    print(f'Plot saved to {save_path}')

    # Show the plot
    plt.show()
    
    plt.close()
# Out:
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/no_mods/PME_no_mod_2024.3_lambda_0.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/no_mods/PME_no_mod_2024.3_lambda_1.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/no_mods/PME_no_mod_2024.3_lambda_2.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/no_mods/PME_no_mod_2024.3_lambda_3.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/no_mods/PME_no_mod_2024.3_lambda_4.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/no_mods/PME_no_mod_2024.3_lambda_5.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/no_mods/PME_no_mod_2024.3_lambda_6.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/no_mods/PME_no_mod_2024.3_lambda_7.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/no_mods/PME_no_mod_2024.3_lambda_8.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/no_mods/PME_no_mod_2024.3_lambda_9.000.png
# Plot saved to /home/lindseywhitmore/projects/lennard-jones-miniproject/lj/FE/2024.3_tests/PME_simple_lj/figs/no_mods/PME_no_mod_2024.3_lambda_10.000.png
